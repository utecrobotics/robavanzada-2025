# %%
# Winter is here. You and your friends were tossing around a frisbee at the
# park when you made a wild throw that left the frisbee out in the middle of
# the lake. The water is mostly frozen, but there are a few holes where the
# ice has melted. If you step into one of those holes, you'll fall into the
# freezing water. At this time, there's an international frisbee shortage, so
# it's absolutely imperative that you navigate across the lake and retrieve
# the disc. However, the ice is slippery, so you won't always move in the
# direction you intend.
# The surface is described using a grid like the following
#    SFFF
#    FHFH
#    FFFH
#    HFFG
# S : starting point, safe
# F : frozen surface, safe
# H : hole, fall to your doom
# G : goal, where the frisbee is located
# The episode ends when you reach the goal or fall in a hole.
# You receive a reward of 1 if you reach the goal, and zero otherwise.

# %%
import gym
import time
import random
import numpy as np
from IPython.display import clear_output

# %%
env = gym.make("FrozenLake-v1")
# MAPS = { "4x4": ["SFFF", "FHFH", "FFFH", "HFFG"] }
# Out:
# /usr/local/lib/python3.7/dist-packages/gym/core.py:318: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   "Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future."
# /usr/local/lib/python3.7/dist-packages/gym/wrappers/step_api_compatibility.py:40: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   "Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future."

# %%
# Possible actions: LEFT = 0, DOWN = 1, RIGHT = 2, UP = 3
print(env.action_space)
print(env.action_space.sample()) # Random actions
# Out:
# Discrete(4)
# 2

# %%
action_space_size = env.action_space.n
state_space_size = env.observation_space.n
print("Cantidad de acciones posibles: "+str(action_space_size))
print("Cantidad de estados posibles: "+str(state_space_size))
# Out:
# Cantidad de acciones posibles: 4
# Cantidad de estados posibles: 16

# %%
q_table = np.zeros((state_space_size,action_space_size))
print("La tabla tiene "+str(q_table.shape[0])+" filas y "+str(q_table.shape[1])+" columnas")
# Out:
# La tabla tiene 16 filas y 4 columnas

# %%
num_episodes = 10000
max_step_per_episode = 100

learning_rate = 0.1
discount_rate= 0.99

exploration_rate = 1
max_exploration_rate = 1
min_exploration_rate = 0.01
exploration_decay_rate = 0.01
